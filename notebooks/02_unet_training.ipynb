# %% [markdown]
# UNET NOTEBOOK

# %%
import os
import copy
import torch
import sys
import torch.optim as optim
import matplotlib.pyplot as plt

from pathlib import Path
from torch.utils.data import DataLoader

# %%
p = Path.cwd().resolve()
repo_root = next(parent for parent in [p, *p.parents] if (parent / "scripts").exists())
sys.path.insert(0, str(repo_root / "scripts"))

# %%
from voc_datasets import build_voc_datasets, NUM_CLASSES, IGNORE_INDEX
from unet import UNet
from losses import get_ce_loss
from train_utils import train_one_epoch, validate_one_epoch, save_checkpoint, count_parameters

# %%
#CONFIG
ROOT = r"c:/Users/Kwame Boateng/Documents/GitHub/semantic-segmentation/Data"
IMG_SIZE = 256
BATCH_SIZE = 8
NUM_EPOCHS = 50
LEARNING_RATE = 1e-4
NUM_WORKERS = 2

CHECKPOINT_DIR = "checkpoints"
os.makedirs(CHECKPOINT_DIR, exist_ok=True)

BEST_MODEL_PATH = os.path.join(CHECKPOINT_DIR, "unet_best.pt")
LAST_MODEL_PATH = os.path.join(CHECKPOINT_DIR, "unet_last.pt")

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)
# Out:
# Device: cuda

# %%
train_dataset, val_dataset = build_voc_datasets(
    root=ROOT,
    img_size=IMG_SIZE
)

print("Train samples:", len(train_dataset))
print("Val samples:", len(val_dataset))
# Out:
# c:\Users\Kwame Boateng\AppData\Local\Programs\Python\Python313\Lib\site-packages\torchvision\transforms\v2\_deprecated.py:42: UserWarning: The transform `ToTensor()` is deprecated and will be removed in a future release. Instead, please use `v2.Compose([v2.ToImage(), v2.ToDtype(torch.float32, scale=True)])`.Output is equivalent up to float precision.
#   warnings.warn(
# Train samples: 209
# Val samples: 213

# %%
#Load Data
train_loader = DataLoader(
    train_dataset,
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=NUM_WORKERS,
    pin_memory=torch.cuda.is_available()
)

val_loader = DataLoader(
    val_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=NUM_WORKERS,
    pin_memory=torch.cuda.is_available()
)

images, masks = next(iter(train_loader))
print("Batch image shape:", images.shape)
print("Batch mask shape:", masks.shape)
# Out:
# Batch image shape: torch.Size([8, 3, 256, 256])
# Batch mask shape: torch.Size([8, 256, 256])

# %%
#Create model
model = UNet(in_channels=3, num_classes=NUM_CLASSES).to(device)
criterion = get_ce_loss(ignore_index=IGNORE_INDEX)
optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)

print(model)
print("Trainable parameters:", count_parameters(model))
# Out:
# UNet(
#   (inc): DoubleConv(
#     (layers): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#     )
#   )
#   (down1): Down(
#     (down): Sequential(
#       (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (1): DoubleConv(
#         (layers): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#           (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU()
#         )
#       )
#     )
#   )
#   (down2): Down(
#     (down): Sequential(
#       (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (1): DoubleConv(
#         (layers): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#           (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU()
#         )
#       )
#     )
#   )
#   (down3): Down(
#     (down): Sequential(
#       (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (1): DoubleConv(
#         (layers): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#           (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU()
#         )
#       )
#     )
#   )
#   (down4): Down(
#     (down): Sequential(
#       (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (1): DoubleConv(
#         (layers): Sequential(
#           (0): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#           (3): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU()
#         )
#       )
#     )
#   )
#   (up1): Up(
#     (up): Upsample(scale_factor=2.0, mode='bilinear')
#     (conv): DoubleConv(
#       (layers): Sequential(
#         (0): Conv2d(1536, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU()
#       )
#     )
#   )
#   (up2): Up(
#     (up): Upsample(scale_factor=2.0, mode='bilinear')
#     (conv): DoubleConv(
#       (layers): Sequential(
#         (0): Conv2d(768, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU()
#       )
#     )
#   )
#   (up3): Up(
#     (up): Upsample(scale_factor=2.0, mode='bilinear')
#     (conv): DoubleConv(
#       (layers): Sequential(
#         (0): Conv2d(384, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU()
#       )
#     )
#   )
#   (up4): Up(
#     (up): Upsample(scale_factor=2.0, mode='bilinear')
#     (conv): DoubleConv(
#       (layers): Sequential(
#         (0): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU()
#       )
#     )
#   )
#   (outc): OutConv(
#     (conv): Conv2d(64, 21, kernel_size=(1, 1), stride=(1, 1))
#   )
# )
# Trainable parameters: 31392021

# %%
history = {
    "train_loss": [],
    "train_pixel_acc": [],
    "train_mean_iou": [],
    "train_mean_dice": [],
    "val_loss": [],
    "val_pixel_acc": [],
    "val_mean_iou": [],
    "val_mean_dice": [],
}

best_val_miou = -1.0
best_epoch = -1
best_model_state = None

# %%
#Training Loop
for epoch in range(NUM_EPOCHS):
    train_metrics = train_one_epoch(
        model=model,
        dataloader=train_loader,
        optimizer=optimizer,
        criterion=criterion,
        device=device,
        num_classes=NUM_CLASSES,
        ignore_index=IGNORE_INDEX,
    )

    val_metrics = validate_one_epoch(
        model=model,
        dataloader=val_loader,
        criterion=criterion,
        device=device,
        num_classes=NUM_CLASSES,
        ignore_index=IGNORE_INDEX,
    )

    history["train_loss"].append(train_metrics["loss"])
    history["train_pixel_acc"].append(train_metrics["pixel_acc"])
    history["train_mean_iou"].append(train_metrics["mean_iou"])
    history["train_mean_dice"].append(train_metrics["mean_dice"])

    history["val_loss"].append(val_metrics["loss"])
    history["val_pixel_acc"].append(val_metrics["pixel_acc"])
    history["val_mean_iou"].append(val_metrics["mean_iou"])
    history["val_mean_dice"].append(val_metrics["mean_dice"])

    print(f"Epoch [{epoch + 1}/{NUM_EPOCHS}]")
    print(
        f"  Train | Loss: {train_metrics['loss']:.4f} | "
        f"Pixel Acc: {train_metrics['pixel_acc']:.4f} | "
        f"mIoU: {train_metrics['mean_iou']:.4f} | "
        f"mDice: {train_metrics['mean_dice']:.4f}"
    )
    print(
        f"  Val   | Loss: {val_metrics['loss']:.4f} | "
        f"Pixel Acc: {val_metrics['pixel_acc']:.4f} | "
        f"mIoU: {val_metrics['mean_iou']:.4f} | "
        f"mDice: {val_metrics['mean_dice']:.4f}"
    )

    save_checkpoint(
        model=model,
        optimizer=optimizer,
        epoch=epoch,
        metrics=val_metrics,
        save_path=LAST_MODEL_PATH,
    )

    if val_metrics["mean_iou"] > best_val_miou:
        best_val_miou = val_metrics["mean_iou"]
        best_epoch = epoch + 1
        best_model_state = copy.deepcopy(model.state_dict())

        save_checkpoint(
            model=model,
            optimizer=optimizer,
            epoch=epoch,
            metrics=val_metrics,
            save_path=BEST_MODEL_PATH,
        )

        print(f"  Saved new best model at epoch {best_epoch} with val mIoU = {best_val_miou:.4f}")

    print("-" * 60)
# Out:
# Epoch [1/50]
#   Train | Loss: 2.7360 | Pixel Acc: 0.4040 | mIoU: 0.0310 | mDice: 0.0454
#   Val   | Loss: 2.0820 | Pixel Acc: 0.7378 | mIoU: 0.0636 | mDice: 0.0732
#   Saved new best model at epoch 1 with val mIoU = 0.0636
# ------------------------------------------------------------
# Epoch [2/50]
#   Train | Loss: 2.4422 | Pixel Acc: 0.5736 | mIoU: 0.0419 | mDice: 0.0564
#   Val   | Loss: 2.4951 | Pixel Acc: 0.5553 | mIoU: 0.0398 | mDice: 0.0523
# ------------------------------------------------------------
# Epoch [3/50]
#   Train | Loss: 2.3000 | Pixel Acc: 0.5959 | mIoU: 0.0444 | mDice: 0.0581
#   Val   | Loss: 2.5200 | Pixel Acc: 0.4874 | mIoU: 0.0362 | mDice: 0.0494
# ------------------------------------------------------------
# Epoch [4/50]
#   Train | Loss: 2.1766 | Pixel Acc: 0.5797 | mIoU: 0.0505 | mDice: 0.0668
#   Val   | Loss: 2.3293 | Pixel Acc: 0.5327 | mIoU: 0.0460 | mDice: 0.0607
# ------------------------------------------------------------
# Epoch [5/50]
#   Train | Loss: 2.0638 | Pixel Acc: 0.5989 | mIoU: 0.0593 | mDice: 0.0769
#   Val   | Loss: 2.6293 | Pixel Acc: 0.5507 | mIoU: 0.0563 | mDice: 0.0736
# ------------------------------------------------------------
# Epoch [6/50]
#   Train | Loss: 2.0149 | Pixel Acc: 0.5789 | mIoU: 0.0691 | mDice: 0.0899
#   Val   | Loss: 2.0229 | Pixel Acc: 0.5591 | mIoU: 0.0643 | mDice: 0.0836
#   Saved new best model at epoch 6 with val mIoU = 0.0643
# ------------------------------------------------------------
# Epoch [7/50]
#   Train | Loss: 1.9034 | Pixel Acc: 0.6141 | mIoU: 0.0769 | mDice: 0.0982
#   Val   | Loss: 1.8872 | Pixel Acc: 0.6402 | mIoU: 0.0812 | mDice: 0.1019
#   Saved new best model at epoch 7 with val mIoU = 0.0812
# ------------------------------------------------------------
# Epoch [8/50]
#   Train | Loss: 1.8246 | Pixel Acc: 0.6209 | mIoU: 0.0851 | mDice: 0.1090
#   Val   | Loss: 1.9078 | Pixel Acc: 0.5662 | mIoU: 0.0750 | mDice: 0.0975
# ------------------------------------------------------------
# Epoch [9/50]
#   Train | Loss: 1.7538 | Pixel Acc: 0.6441 | mIoU: 0.0837 | mDice: 0.1059
#   Val   | Loss: 2.0741 | Pixel Acc: 0.6060 | mIoU: 0.0831 | mDice: 0.1060
#   Saved new best model at epoch 9 with val mIoU = 0.0831
# ------------------------------------------------------------
# Epoch [10/50]
#   Train | Loss: 1.6825 | Pixel Acc: 0.6450 | mIoU: 0.0918 | mDice: 0.1159
#   Val   | Loss: 2.0722 | Pixel Acc: 0.6177 | mIoU: 0.0792 | mDice: 0.1003
# ------------------------------------------------------------
# Epoch [11/50]
#   Train | Loss: 1.6378 | Pixel Acc: 0.6569 | mIoU: 0.0906 | mDice: 0.1142
#   Val   | Loss: 1.6024 | Pixel Acc: 0.6871 | mIoU: 0.0891 | mDice: 0.1103
#   Saved new best model at epoch 11 with val mIoU = 0.0891
# ------------------------------------------------------------
# Epoch [12/50]
#   Train | Loss: 1.5767 | Pixel Acc: 0.6843 | mIoU: 0.0902 | mDice: 0.1111
#   Val   | Loss: 1.8423 | Pixel Acc: 0.6394 | mIoU: 0.0840 | mDice: 0.1053
# ------------------------------------------------------------
# Epoch [13/50]
#   Train | Loss: 1.5266 | Pixel Acc: 0.6891 | mIoU: 0.0918 | mDice: 0.1132
#   Val   | Loss: 1.4282 | Pixel Acc: 0.7336 | mIoU: 0.0952 | mDice: 0.1164
#   Saved new best model at epoch 13 with val mIoU = 0.0952
# ------------------------------------------------------------
# Epoch [14/50]
#   Train | Loss: 1.4552 | Pixel Acc: 0.7200 | mIoU: 0.1028 | mDice: 0.1265
#   Val   | Loss: 1.5317 | Pixel Acc: 0.7128 | mIoU: 0.0931 | mDice: 0.1144
# ------------------------------------------------------------
# Epoch [15/50]
#   Train | Loss: 1.4306 | Pixel Acc: 0.7149 | mIoU: 0.1031 | mDice: 0.1264
#   Val   | Loss: 1.6027 | Pixel Acc: 0.7014 | mIoU: 0.0915 | mDice: 0.1125
# ------------------------------------------------------------
# Epoch [16/50]
#   Train | Loss: 1.4003 | Pixel Acc: 0.7195 | mIoU: 0.0978 | mDice: 0.1195
#   Val   | Loss: 1.5475 | Pixel Acc: 0.6877 | mIoU: 0.0909 | mDice: 0.1122
# ------------------------------------------------------------
# Epoch [17/50]
#   Train | Loss: 1.3479 | Pixel Acc: 0.7284 | mIoU: 0.1045 | mDice: 0.1265
#   Val   | Loss: 1.4896 | Pixel Acc: 0.6951 | mIoU: 0.0898 | mDice: 0.1112
# ------------------------------------------------------------
# Epoch [18/50]
#   Train | Loss: 1.3002 | Pixel Acc: 0.7395 | mIoU: 0.1015 | mDice: 0.1242
#   Val   | Loss: 1.4290 | Pixel Acc: 0.7053 | mIoU: 0.0916 | mDice: 0.1127
# ------------------------------------------------------------
# Epoch [19/50]
#   Train | Loss: 1.2796 | Pixel Acc: 0.7381 | mIoU: 0.1022 | mDice: 0.1236
#   Val   | Loss: 1.3135 | Pixel Acc: 0.7184 | mIoU: 0.0978 | mDice: 0.1197
#   Saved new best model at epoch 19 with val mIoU = 0.0978
# ------------------------------------------------------------
# Epoch [20/50]
#   Train | Loss: 1.2682 | Pixel Acc: 0.7337 | mIoU: 0.1046 | mDice: 0.1276
#   Val   | Loss: 1.6178 | Pixel Acc: 0.6512 | mIoU: 0.0854 | mDice: 0.1068
# ------------------------------------------------------------
# Epoch [21/50]
#   Train | Loss: 1.2341 | Pixel Acc: 0.7357 | mIoU: 0.0994 | mDice: 0.1214
#   Val   | Loss: 1.2584 | Pixel Acc: 0.7384 | mIoU: 0.0946 | mDice: 0.1157
# ------------------------------------------------------------
# Epoch [22/50]
#   Train | Loss: 1.1802 | Pixel Acc: 0.7481 | mIoU: 0.1055 | mDice: 0.1291
#   Val   | Loss: 1.3905 | Pixel Acc: 0.6956 | mIoU: 0.0942 | mDice: 0.1175
# ------------------------------------------------------------
# Epoch [23/50]
#   Train | Loss: 1.1669 | Pixel Acc: 0.7457 | mIoU: 0.1106 | mDice: 0.1354
#   Val   | Loss: 1.5687 | Pixel Acc: 0.6521 | mIoU: 0.0851 | mDice: 0.1059
# ------------------------------------------------------------
# Epoch [24/50]
#   Train | Loss: 1.1391 | Pixel Acc: 0.7512 | mIoU: 0.1087 | mDice: 0.1324
#   Val   | Loss: 1.2782 | Pixel Acc: 0.7231 | mIoU: 0.0944 | mDice: 0.1160
# ------------------------------------------------------------
# Epoch [25/50]
#   Train | Loss: 1.1249 | Pixel Acc: 0.7437 | mIoU: 0.1022 | mDice: 0.1234
#   Val   | Loss: 1.3942 | Pixel Acc: 0.6785 | mIoU: 0.0945 | mDice: 0.1193
# ------------------------------------------------------------
# Epoch [26/50]
#   Train | Loss: 1.1141 | Pixel Acc: 0.7554 | mIoU: 0.1094 | mDice: 0.1327
#   Val   | Loss: 1.2986 | Pixel Acc: 0.7224 | mIoU: 0.0968 | mDice: 0.1202
# ------------------------------------------------------------
# Epoch [27/50]
#   Train | Loss: 1.0947 | Pixel Acc: 0.7573 | mIoU: 0.1082 | mDice: 0.1312
#   Val   | Loss: 1.2195 | Pixel Acc: 0.7301 | mIoU: 0.0947 | mDice: 0.1157
# ------------------------------------------------------------
# Epoch [28/50]
#   Train | Loss: 1.0460 | Pixel Acc: 0.7645 | mIoU: 0.1149 | mDice: 0.1399
#   Val   | Loss: 1.2194 | Pixel Acc: 0.7279 | mIoU: 0.0963 | mDice: 0.1194
# ------------------------------------------------------------
# Epoch [29/50]
#   Train | Loss: 1.0609 | Pixel Acc: 0.7580 | mIoU: 0.1151 | mDice: 0.1400
#   Val   | Loss: 1.2075 | Pixel Acc: 0.7342 | mIoU: 0.0908 | mDice: 0.1115
# ------------------------------------------------------------
# Epoch [30/50]
#   Train | Loss: 1.0203 | Pixel Acc: 0.7679 | mIoU: 0.1243 | mDice: 0.1494
#   Val   | Loss: 1.4036 | Pixel Acc: 0.6829 | mIoU: 0.0928 | mDice: 0.1161
# ------------------------------------------------------------
# Epoch [31/50]
#   Train | Loss: 1.0117 | Pixel Acc: 0.7651 | mIoU: 0.1143 | mDice: 0.1374
#   Val   | Loss: 1.3641 | Pixel Acc: 0.6866 | mIoU: 0.0957 | mDice: 0.1189
# ------------------------------------------------------------
# Epoch [32/50]
#   Train | Loss: 0.9770 | Pixel Acc: 0.7733 | mIoU: 0.1211 | mDice: 0.1464
#   Val   | Loss: 1.1763 | Pixel Acc: 0.7384 | mIoU: 0.0938 | mDice: 0.1150
# ------------------------------------------------------------
# Epoch [33/50]
#   Train | Loss: 0.9807 | Pixel Acc: 0.7728 | mIoU: 0.1087 | mDice: 0.1313
#   Val   | Loss: 1.2412 | Pixel Acc: 0.7192 | mIoU: 0.0955 | mDice: 0.1179
# ------------------------------------------------------------
# Epoch [34/50]
#   Train | Loss: 0.9652 | Pixel Acc: 0.7727 | mIoU: 0.1192 | mDice: 0.1446
#   Val   | Loss: 1.1849 | Pixel Acc: 0.7433 | mIoU: 0.0845 | mDice: 0.1032
# ------------------------------------------------------------
# Epoch [35/50]
#   Train | Loss: 0.9729 | Pixel Acc: 0.7704 | mIoU: 0.1201 | mDice: 0.1438
#   Val   | Loss: 1.2031 | Pixel Acc: 0.7311 | mIoU: 0.0981 | mDice: 0.1201
#   Saved new best model at epoch 35 with val mIoU = 0.0981
# ------------------------------------------------------------
# Epoch [36/50]
#   Train | Loss: 0.9629 | Pixel Acc: 0.7691 | mIoU: 0.1157 | mDice: 0.1390
#   Val   | Loss: 1.3976 | Pixel Acc: 0.6740 | mIoU: 0.0849 | mDice: 0.1082
# ------------------------------------------------------------
# Epoch [37/50]
#   Train | Loss: 0.9636 | Pixel Acc: 0.7702 | mIoU: 0.1131 | mDice: 0.1359
#   Val   | Loss: 1.2050 | Pixel Acc: 0.7227 | mIoU: 0.0953 | mDice: 0.1183
# ------------------------------------------------------------
# Epoch [38/50]
#   Train | Loss: 0.9277 | Pixel Acc: 0.7788 | mIoU: 0.1206 | mDice: 0.1456
#   Val   | Loss: 1.2125 | Pixel Acc: 0.7221 | mIoU: 0.0879 | mDice: 0.1101
# ------------------------------------------------------------
# Epoch [39/50]
#   Train | Loss: 0.9137 | Pixel Acc: 0.7793 | mIoU: 0.1151 | mDice: 0.1385
#   Val   | Loss: 1.1976 | Pixel Acc: 0.7207 | mIoU: 0.0861 | mDice: 0.1075
# ------------------------------------------------------------
# Epoch [40/50]
#   Train | Loss: 0.8927 | Pixel Acc: 0.7820 | mIoU: 0.1200 | mDice: 0.1449
#   Val   | Loss: 1.1802 | Pixel Acc: 0.7226 | mIoU: 0.0916 | mDice: 0.1137
# ------------------------------------------------------------
# Epoch [41/50]
#   Train | Loss: 0.8903 | Pixel Acc: 0.7775 | mIoU: 0.1118 | mDice: 0.1363
#   Val   | Loss: 1.2229 | Pixel Acc: 0.7304 | mIoU: 0.0907 | mDice: 0.1112
# ------------------------------------------------------------
# Epoch [42/50]
#   Train | Loss: 0.8614 | Pixel Acc: 0.7862 | mIoU: 0.1183 | mDice: 0.1431
#   Val   | Loss: 1.2033 | Pixel Acc: 0.7321 | mIoU: 0.0767 | mDice: 0.0947
# ------------------------------------------------------------
# Epoch [43/50]
#   Train | Loss: 0.8836 | Pixel Acc: 0.7826 | mIoU: 0.1142 | mDice: 0.1395
#   Val   | Loss: 1.4398 | Pixel Acc: 0.6478 | mIoU: 0.0826 | mDice: 0.1034
# ------------------------------------------------------------
# Epoch [44/50]
#   Train | Loss: 0.8668 | Pixel Acc: 0.7838 | mIoU: 0.1180 | mDice: 0.1408
#   Val   | Loss: 1.1573 | Pixel Acc: 0.7317 | mIoU: 0.0892 | mDice: 0.1120
# ------------------------------------------------------------
# Epoch [45/50]
#   Train | Loss: 0.8183 | Pixel Acc: 0.7933 | mIoU: 0.1288 | mDice: 0.1564
#   Val   | Loss: 1.1663 | Pixel Acc: 0.7402 | mIoU: 0.0908 | mDice: 0.1127
# ------------------------------------------------------------
# Epoch [46/50]
#   Train | Loss: 0.8326 | Pixel Acc: 0.7850 | mIoU: 0.1135 | mDice: 0.1370
#   Val   | Loss: 1.2225 | Pixel Acc: 0.7117 | mIoU: 0.0836 | mDice: 0.1054
# ------------------------------------------------------------
# Epoch [47/50]
#   Train | Loss: 0.8245 | Pixel Acc: 0.7915 | mIoU: 0.1232 | mDice: 0.1499
#   Val   | Loss: 1.1761 | Pixel Acc: 0.7239 | mIoU: 0.0864 | mDice: 0.1093
# ------------------------------------------------------------
# Epoch [48/50]
#   Train | Loss: 0.7954 | Pixel Acc: 0.8005 | mIoU: 0.1290 | mDice: 0.1545
#   Val   | Loss: 1.2040 | Pixel Acc: 0.7259 | mIoU: 0.0869 | mDice: 0.1104
# ------------------------------------------------------------
# Epoch [49/50]
#   Train | Loss: 0.7994 | Pixel Acc: 0.7990 | mIoU: 0.1279 | mDice: 0.1558
#   Val   | Loss: 1.1742 | Pixel Acc: 0.7197 | mIoU: 0.0825 | mDice: 0.1034
# ------------------------------------------------------------
# Epoch [50/50]
#   Train | Loss: 0.7683 | Pixel Acc: 0.8017 | mIoU: 0.1245 | mDice: 0.1480
#   Val   | Loss: 1.2667 | Pixel Acc: 0.6907 | mIoU: 0.0827 | mDice: 0.1062
# ------------------------------------------------------------

# %%
if best_model_state is not None:
    model.load_state_dict(best_model_state)

print("Best epoch:", best_epoch)
print("Best val mIoU:", best_val_miou)
# Out:
# Best epoch: 35
# Best val mIoU: 0.0980916657778019

# %%
epochs = range(1, NUM_EPOCHS + 1)

#Training Loss
plt.figure(figsize=(8, 5))
plt.plot(epochs, history["train_loss"], label="Train Loss")
plt.plot(epochs, history["val_loss"], label="Val Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Loss Curve")
plt.legend()
plt.show()

# %%
#mIOU
plt.figure(figsize=(8, 5))
plt.plot(epochs, history["train_mean_iou"], label="Train mIoU")
plt.plot(epochs, history["val_mean_iou"], label="Val mIoU")
plt.xlabel("Epoch")
plt.ylabel("mIoU")
plt.title("mIoU Curve")
plt.legend()
plt.show()

# %%
#Dice
plt.figure(figsize=(8, 5))
plt.plot(epochs, history["train_mean_dice"], label="Train mDice")
plt.plot(epochs, history["val_mean_dice"], label="Val mDice")
plt.xlabel("Epoch")
plt.ylabel("mDice")
plt.title("Mean Dice Curve")
plt.legend()
plt.show()

# %%
#Validation Pass
final_val_metrics = validate_one_epoch(
    model=model,
    dataloader=val_loader,
    criterion=criterion,
    device=device,
    num_classes=NUM_CLASSES,
    ignore_index=IGNORE_INDEX,
)

print("Final validation metrics (best loaded model):")
for k, v in final_val_metrics.items():
    print(f"{k}: {v:.4f}")
# Out:
# Final validation metrics (best loaded model):
# loss: 1.2031
# pixel_acc: 0.7311
# mean_iou: 0.0981
# mean_dice: 0.1201
